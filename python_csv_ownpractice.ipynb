# %%
# %pwd
# Out:
# 'C:\\Users\\ameli\\OneDrive - SIM - Singapore Institute of Management\\ST2195 Programming for DS\\Workshop\\gitAME\\st2195_assignment_2'

# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import bs4

# %%
wikicars_url = "https://en.wikipedia.org/wiki/Comma-separated_values"
wikicars = requests.get(wikicars_url)

# %%
wikicars.status_code
# Out:
# 200

# %%
#200 means request was successful 
wikicars.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>Comma-separated values - Wikipedia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-client
# ...

# %%
soup = bs4.BeautifulSoup(wikicars.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Comma-separated values - Wikipedia</title>
# ...

# %%
table = soup.find_all('table')[1]
table
# Out:
# <table class="wikitable">
# <tbody><tr>
# <th>Year</th>
# <th>Make</th>
# <th>Model</th>
# <th>Description</th>
# <th>Price
# </th></tr>
# <tr>
# <td>1997</td>
# <td>Ford</td>
# <td>E350</td>
# <td>ac, abs, moon</td>
# <td>3000.00
# </td></tr>
# <tr>
# <td>1999</td>
# <td>Chevy</td>
# <td>Venture "Extended Edition"</td>
# <td></td>
# <td>4900.00
# </td></tr>
# <tr>
# <td>1999</td>
# <td>Chevy</td>
# <td>Venture "Extended Edition, Very Large"</td>
# <td></td>
# <td>5000.00
# </td></tr>
# <tr>
# <td>1996</td>
# <td>Jeep</td>
# <td>Grand Cherokee</td>
# <td>MUST SELL!<br/>air, moon roof, loaded</td>
# <td>4799.00
# </td></tr></tbody></table>

# %%
headers = [header.text.strip() for header in table.find_all('th')]
headers
# Out:
# ['Year', 'Make', 'Model', 'Description', 'Price']

# %%
data = []
for row in rows[1:]:
    cells = row.find_all('td')
    year = cells[0].text.strip()
    make = cells[1].text.strip()
    model = cells[2].text.strip()
    description = cells[3].text.strip()
    price = cells[4].text.strip()
    print(year, make, model, description, price)
    print()
# Out:
# 1997 Ford E350 ac, abs, moon 3000.00
#
# 1999 Chevy Venture "Extended Edition"  4900.00
#
# 1999 Chevy Venture "Extended Edition, Very Large"  5000.00
#
# 1996 Jeep Grand Cherokee MUST SELL!air, moon roof, loaded 4799.00

# %%
import pandas as pd
import csv

# %%
for item in data:
    print(item)

# %%
data = []
for row in table.find_all('tr')[1:]:
    cells = row.find_all('td')
    if cells:
        row_data = {headers[i]: cells[i].text.strip() for i in range(len(cells))}
        data.append(row_data)

# %%
data
# Out:
# [{'Year': '1997',
#   'Make': 'Ford',
#   'Model': 'E350',
#   'Description': 'ac, abs, moon',
#   'Price': '3000.00'},
#  {'Year': '1999',
#   'Make': 'Chevy',
#   'Model': 'Venture "Extended Edition"',
#   'Description': '',
#   'Price': '4900.00'},
#  {'Year': '1999',
#   'Make': 'Chevy',
#   'Model': 'Venture "Extended Edition, Very Large"',
#   'Description': '',
#   'Price': '5000.00'},
#  {'Year': '1996',
#   'Make': 'Jeep',
#   'Model': 'Grand Cherokee',
#   'Description': 'MUST SELL!air, moon roof, loaded',
#   'Price': '4799.00'}]

# %%
for item in data:
    print(item)
# Out:
# {'Year': '1997', 'Make': 'Ford', 'Model': 'E350', 'Description': 'ac, abs, moon', 'Price': '3000.00'}
# {'Year': '1999', 'Make': 'Chevy', 'Model': 'Venture "Extended Edition"', 'Description': '', 'Price': '4900.00'}
# {'Year': '1999', 'Make': 'Chevy', 'Model': 'Venture "Extended Edition, Very Large"', 'Description': '', 'Price': '5000.00'}
# {'Year': '1996', 'Make': 'Jeep', 'Model': 'Grand Cherokee', 'Description': 'MUST SELL!air, moon roof, loaded', 'Price': '4799.00'}

# %%
with open('wikicars_withpython.csv','w', newline='', encoding = 'utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(data)

# %%
print("Data has been written to wikicars_withpython.csv")
# Out:
# Data has been written to wikicars_withpython.csv
